# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# %%
dane00=pd.read_csv('pokemon_data.csv')

# %%
dane00
# Out:
#       dexnum          name  generation     type1    type2  \
# 0          1     Bulbasaur           1     Grass   Poison
# 1          2       Ivysaur           1     Grass   Poison
# 2          3      Venusaur           1     Grass   Poison
# 3          4    Charmander           1      Fire      NaN
# 4          5    Charmeleon           1      Fire      NaN
# ...      ...           ...         ...       ...      ...
# 1020    1021   Raging Bolt           9  Electric   Dragon
# 1021    1022  Iron Boulder           9      Rock  Psychic
# 1022    1023    Iron Crown           9     Steel  Psychic
# 1023    1024     Terapagos           9    Normal      NaN
# 1024    1025     Pecharunt           9    Poison    Ghost
#
#                   species  height  weight          ability1     ability2  ...  \
# 0            Seed Pokémon     0.7     6.9          Overgrow  Chlorophyll  ...
# 1            Seed Pokémon     1.0    13.0          Overgrow  Chlorophyll  ...
# ...

# %%
#procent meskich i zenskich pokemonow wedlug typu pierwszego pokemonow
daneG_typ1=dane00.groupby('type1')
srednie_typ_plec=daneG_typ1[['percent_male','percent_female']].mean().reset_index()
srednie_typ_plec.columns=['Typ','%male','%female']
srednie_typ_plec['%male neg']=srednie_typ_plec['%male']*(-1)

# %%
fig, ax = plt.subplots(figsize=(16,9))

plt.barh(srednie_typ_plec['Typ'],srednie_typ_plec['%female'],color='#e99346',edgecolor='#2f5f6d',linewidth=2,label='Female')
plt.barh(srednie_typ_plec['Typ'],srednie_typ_plec['%male neg'],color='#2596be',edgecolor='#2f5f6d',linewidth=2,label='Male')

plt.title('Average Gender Distribution of Pokémon by Primary Type', fontsize=16)
plt.xlabel('Average Percentage per Species')
plt.ylabel('Pokémon Type')

plt.grid(axis='x', alpha=0.5)
znaczniki=[-100,-75,-50,-25,0,25,50,75,100] #znaczniki na osi x
nowe_ticks= [f'{abs(x):.0f}%' if abs(x)!=100 else "" for x in znaczniki]
plt.xticks(znaczniki,nowe_ticks)

img = plt.imread('images/images/6.png')
imagebox = OffsetImage(img, zoom=0.3) 
# ustawienie pozycji (w układzie współrzędnych danych wykresu)
# xy to współrzędne, w których ma się pojawić obrazek
ab = AnnotationBbox(imagebox, xy=(86, 0.1), frameon=False)

ax.add_artist(ab)

plt.tight_layout()
plt.legend(title='Gender')
plt.savefig('gender01.png')
plt.show()

#legenda!!

# %%
fig, ax = plt.subplots(figsize=(16,9))

plt.barh(srednie_typ_plec['Typ'],srednie_typ_plec['%female'],color='#e99346',edgecolor='#2f5f6d',linewidth=2,label='Female')
plt.barh(srednie_typ_plec['Typ'],srednie_typ_plec['%male neg'],color='#2596be',edgecolor='#2f5f6d',linewidth=2,label='Male')

plt.title('Average Gender Distribution of Pokémon by Primary Type', fontsize=16)
plt.xlabel('Average Percentage per Species')
plt.ylabel('Pokémon Type')

plt.grid(axis='x', alpha=0.5)
znaczniki=[-100,-75,-50,-25,0,25,50,75,100] #znaczniki na osi x
nowe_ticks= [f'{abs(x):.0f}%' if abs(x)!=100 else "" for x in znaczniki]
plt.xticks(znaczniki,nowe_ticks)

img = plt.imread('images/images/6.png')
imagebox = OffsetImage(img, zoom=0.25) 
ab = AnnotationBbox(imagebox, xy=(91, 1.82), frameon=False)
ax.add_artist(ab)

plt.tight_layout()
plt.legend(title='Gender', loc='lower right')
#plt.savefig('gender01.png')
plt.show()

#legenda!!
