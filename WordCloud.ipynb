# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud

# %%
df1=pd.read_csv('pokemon_data.csv')

# %%
df2=pd.read_csv('pokemon_data.csv').set_index(x)

# %%
x=np.arange(1025, 2050)

# %%
df=pd.concat([df1['type1'],df2['type2']])
df
# Out:
# 0         Grass
# 1         Grass
# 2         Grass
# 3          Fire
# 4          Fire
#          ...
# 2045     Dragon
# 2046    Psychic
# 2047    Psychic
# 2048        NaN
# 2049      Ghost
# Length: 2050, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 2050 entries, 0 to 2049
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 1551 non-null   object
# dtypes: object(1)
# memory usage: 32.0+ KB

# %%
type_string=df.str.cat(sep=' ')
wordcloud=WordCloud(
    background_color='white',
    width=1600,
    height=800
)
wordcloud.generate(type_string)
plt.figure(figsize=(16,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1599.5), np.float64(799.5), np.float64(-0.5))
